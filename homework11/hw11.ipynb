# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# Your comment here
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.
# Signed, Jonathan Zhang

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Your code here (WITHOUT NUMPY! or any other modules/libraries/packages)
def orbital_period(a):
    """
    Calculate the orbital period proportional to a^(3/2).

    Parameters:
    a (float): Semi-major axis (must be positive).

    Returns:
    float: Orbital period proportional to a^(3/2).
    """
    return (a ** 3) ** 0.5

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
# Your code here
planet_a = orbital_period(0.5)
planet_b = orbital_period(1.0)
planet_c = orbital_period(1.5)

# %% [markdown]
# Import `numpy` in the cell below.

# %%
# Your code here
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Your comment (2 sentences)

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
# Your code here
def orbital_period_numpy(a):
    return np.sqrt(a ** 3)

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
# Your code here
start_time = time.time()
orbital_period(5)
end_time = time.time()

print(end_time - start_time)

start_time = time.time()
orbital_period_numpy(5)
end_time = time.time()

print(end_time - start_time)
# Out:
# 0.0
# 0.0

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your comment here
# The numpy function is often faster (although most of the time the time difference for both is 0.0). 
# Numpy functions are better/faster with numbers than regular functions

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
# Your code here
semi_major_axes = list(np.random.uniform(0.1, 10.0, 1000000))

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
# Your code here
start_time = time.time()
for i in semi_major_axes:
    orbital_period(i)
end_time = time.time()

print("Time without numpy:", end_time - start_time)

start_time = time.time()
for i in semi_major_axes:
    orbital_period_numpy(i)
end_time = time.time()

print("Time with numpy", end_time - start_time)
# Out:
# Time without numpy: 0.7603640556335449
# Time with numpy 2.527503252029419

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Your code here
# Numpy is faster since Numpy is more optimized towards working with numerical values.

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

for i in range(len(radii) - 1):
    if temperatures[i] < 350:
        print(radii[i])
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Your code here
for i in radii[:3]:
    print(i)
# Out:
# 1.2
# 0.8
# 1.5

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
# Your code here
radii_and_temp = {}
for i in range(len(radii) - 1):
    radii_and_temp[radii[i]] = temperatures[i]
print(radii_and_temp)
# Out:
# {1.2: 300, 0.8: 400, 1.5: 350, 2.0: 280, 1.0: 500}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Your code here
names_radii_temp = {}
planet_names = ["Planet A", "Planet B", "Planet C", "Planet D", "Planet E", "Planet F"]

for i in range(len(planet_names) - 1):
    names_radii_temp[planet_names[i]] = (radii[i], temperatures[i])
print(names_radii_temp)
# Out:
# {'Planet A': (1.2, 300), 'Planet B': (0.8, 400), 'Planet C': (1.5, 350), 'Planet D': (2.0, 280), 'Planet E': (1.0, 500)}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Your code here
midsized_planets = {}
for i in names_radii_temp.keys():
    if names_radii_temp[i][0] >= 1.0 and names_radii_temp[i][0] <= 2.0:
        midsized_planets[i] = names_radii_temp[i]
print(midsized_planets)
# Out:
# {'Planet A': (1.2, 300), 'Planet C': (1.5, 350), 'Planet D': (2.0, 280), 'Planet E': (1.0, 500)}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
# Your code here
semi_major_axes_array = np.array(semi_major_axes)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
# Your code here
mean = np.average(semi_major_axes_array)
median = np.median(semi_major_axes_array)
minimum = np.min(semi_major_axes_array)
maximum = np.max(semi_major_axes_array)

print("mean =", mean, "median =", median, "minimum =", minimum, "maximum =", maximum)
# Out:
# mean = 5.047824470660508 median = 5.046526495191675 minimum = 0.1000124667921725 maximum = 9.999975934711241

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
# Your code here
# takes the sum of the array
np.sum(semi_major_axes_array)
# Out:
# 5047824.470660509

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Your code here
planet_data = np.array([radii, temperatures])
planet_data
# Out:
# array([[  1.2,   0.8,   1.5,   2. ,   1. ,   0.6],
#        [300. , 400. , 350. , 280. , 500. , 450. ]])

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
# Your code here
for col in range(len(planet_data[1]) - 1):
    if col == 2:
        print(planet_data[1][col])
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# Your code here
planet_data[1][2]
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# Your code here
import matplotlib.pyplot as plt

semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]

orbital_periods = [a ** (3/2) for a in semi_major_axes]

plt.scatter(semi_major_axes, orbital_periods, label="Orbital Periods", color='b')

plt.xlabel('Semi-Major Axis (AU)')
plt.ylabel('Orbital Period (years)')

plt.title('Orbital Periods of Exoplanets')

plt.legend()

plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
# Your code here
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

plt.bar(radii, temperatures, color='green', label="Equilibrium Temperature")

plt.xlabel('Planet Radii (Earth radii)')
plt.ylabel('Equilibrium Temperature (K)')

plt.title('Equilibrium Temperatures vs. Radii')

plt.legend()

plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
# Your code here
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].scatter(semi_major_axes, orbital_periods, label="Orbital Periods", color='b')
ax[0].set_xlabel('Semi-Major Axis (AU)')
ax[0].set_ylabel('Orbital Period (years)')
ax[0].set_title('Orbital Periods of Exoplanets')
ax[0].legend()

ax[1].bar(radii, temperatures, color='green', label="Equilibrium Temperature")
ax[1].set_xlabel('Planet Radii (Earth radii)')
ax[1].set_ylabel('Equilibrium Temperature (K)')
ax[1].set_title('Equilibrium Temperatures vs. Radii')
ax[1].legend()

plt.show()

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
# Your code here
from orbital_period_module import calculate_orbital_period

result = calculate_orbital_period(1.0)
result
# Out:
# 1.0
